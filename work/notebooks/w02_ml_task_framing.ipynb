# %% [markdown]
# <a href="https://colab.research.google.com/github/ReposofPriyanka/flyrank-ai-internship-ml-track/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ReposofPriyanka/flyrank-ai-internship-ml-track/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Content Ranking / SEO as an ML task
#
# Task Type: Scoring
#
#
# Explanation:
# My lane is Content Ranking/SEO. The goal is to assign each content page a score that reflects how strongly it needs to be refreshed or optimized. Pages with higher scores can be prioritized for updates to improve search visibility and user engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## 2. Target or proxy
# Since there is no explicit needs_refresh column, I would use trend_pct as a proxy target.
#
# A large negative trend_pct indicates that a page's performance is declining and it is more likely to need a content refresh.
#
# Example:
#
# trend_pct
#
# -60.9
#
# -41.4
#
# -13.8

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## 3. Success metric
# For a scoring task, I would measure performance using Mean Absolute Error (MAE) or Root Mean Squared Error (RMSE) if predicting a continuous refresh score.
#
# If the target is converted into a binary label (needs_refresh), I would instead use F1 Score.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
# One row represents one content page and its SEO performance metrics.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd
df = pd.read_csv("data/content_refresh_anonymized.csv")
df.head()

# %% [markdown]
# Each row represents one content page with features describing its search performance, engagement, freshness, and historical trends.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule such as "refresh every page older than 180 days" ignores many important signals.
#
# Machine learning can combine multiple factors—including search volume, CTR, average position, engagement rate, content age, trend percentage, and freshness—to estimate which pages are most likely to benefit from an update. This allows content teams to prioritize the pages that will have the greatest SEO impact instead of relying on simple thresholds.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
pass

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
